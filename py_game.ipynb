# %%
##### for display the tic tac toe board
def Game_board(T):
    print("",T[1]," │",T[2]," │ ",T[3]," ")
    print("────┼────┼────")
    print("",T[4]," │",T[5]," │ ",T[6]," ")
    print("────┼────┼────")
    print("",T[7]," │",T[8]," │ ",T[9]," ")
     
# for display the instruction of game
def Game_instructions():
    print("\n----------- WELCOME TO TIC TAC TOE------------\n------------BE A CHAMPION------------\n")
    Game_board(pos)
    print()
    
    players[0] = input("Player 1 : ")
    players[1] = input("Player 2 : ")
    
    print("\n-------- Instructions ---------")
    print("->",players[0],"you will using X")
    print("->",players[1],"you will using 0")
    print("-> Turn starts from",players[0])
    print("-> Positions are like :-")
    print("  1 │  2 │ 3  ")
    
    print("────┼────┼────")
    
    print("  4 │ 5  │ 6  ")
    
    print("────┼────┼────")
    
    print("  7 │ 8  │ 9  ")
    print("-> press S to start the game")
    game = input()    
    return game
# for start the game
def playnow():
    turn = 0
    for i in range(9):
        if turn % 2 == 0:
            print("\nthis is your turn",players[0])
            p = int(input("Please Enter position : "))
            g = 'x'
            pos[p] = g
            Game_board(pos)
            winner = evaluate_game(g)
            if winner is "nobody":
                turn = 1
                continue
            else:
                print("\n\nCongratulation !!,",players[0],"you are champian")
                break
        else:
            print("\nthis is your turn",players[1])
            p = int(input("Please Enter position : "))
            g = '0'
            pos[p] = g
            Game_board(pos)
            winner = evaluate_game(g)
            if winner is "nobody":
                turn = 0
                continue
            else:
                print("\n\nCongratulation !!,",players[1],"you are champian")    
                break
    else:
        print("\n\nGame is Tie")
# check for winner 
def evaluate_game(g):
    for i in winning_conditions:
        if (pos[i[0]], pos[i[1]], pos[i[2]]) == (g,g,g):
            winner = players[0]
            break
        elif (pos[i[0]], pos[i[1]], pos[i[2]]) == (g,g,g):
            winner = players[1]
            break
    else:
        winner = "nobody"
    return winner
# main code 
pos = ['',' ',' ',' ',' ',' ',' ',' ',' ',' ']
players = ['','']
winning_conditions = [(1,2,3),(4,5,6),(7,8,9),(1,4,7),(2,5,8),(3,6,9),(1,5,9),(3,5,7)]
game = Game_instructions()
if game == 's' or game == 'S':
    playnow()
else:
    print("Invalid Entry")
# Out:
# <>:46: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:59: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:46: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:59: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-4-bd8e6e98b12f>:46: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if winner is "nobody":
# <ipython-input-4-bd8e6e98b12f>:59: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if winner is "nobody":
# ----------- WELCOME TO TIC TAC TOE------------
# ------------BE A CHAMPION------------
#
#     │    │
# ────┼────┼────
#     │    │
# ────┼────┼────
#     │    │
#
# Player 1 : gautam
# Player 2 : sunil
#
# -------- Instructions ---------
# -> gautam you will using X
# -> sunil you will using 0
# -> Turn starts from gautam
# -> Positions are like :-
#   1 │  2 │ 3
# ────┼────┼────
#   4 │ 5  │ 6
# ────┼────┼────
#   7 │ 8  │ 9
# -> press S to start the game
# s
#
# this is your turn gautam
# Please Enter position : 5
#     │    │
# ────┼────┼────
#     │ x  │
# ────┼────┼────
#     │    │
#
# this is your turn sunil
# Please Enter position : 9
#     │    │
# ────┼────┼────
#     │ x  │
# ────┼────┼────
#     │    │  0
#
# this is your turn gautam
# Please Enter position : 3
#     │    │  x
# ────┼────┼────
#     │ x  │
# ────┼────┼────
#     │    │  0
#
# this is your turn sunil
# Please Enter position : 1
#  0  │    │  x
# ────┼────┼────
#     │ x  │
# ────┼────┼────
#     │    │  0
#
# this is your turn gautam
# Please Enter position : 7
#  0  │    │  x
# ────┼────┼────
#     │ x  │
# ────┼────┼────
#  x  │    │  0
#
#
# Congratulation !!, gautam you are champian

# %% [markdown]
# S
